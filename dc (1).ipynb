# %%
import pandas as pd
df=pd.read_csv("covid78.csv")
df
# Out:
#      Unnamed: 0   #  Country,Other     TotalCase  NewCases TotalDeaths  \
# 0             0 NaN  North America   3,95,30,576     8,157    8,85,806
# 1             1 NaN           Asia   4,97,38,601  2,48,218    6,56,920
# 2             2 NaN  South America   2,78,51,515     6,782    7,56,544
# 3             3 NaN         Europe   4,62,83,283    38,828   10,63,480
# 4             4 NaN         Africa     48,13,221     3,652    1,29,083
# ..          ...  ..            ...           ...       ...         ...
# 233         233 NaN         Total:   4,62,83,283    38,828   10,63,480
# 234         234 NaN         Total:     48,13,221     3,652    1,29,083
# 235         235 NaN         Total:        67,626        68       1,245
# 236         236 NaN         Total:           721       NaN          15
# 237         237 NaN         Total:  16,82,85,543  3,05,705   34,93,093
#
#     NewDeaths TotalRecovered NewRecovered  ActiveCases  ... TotalTests  \
# ...

# %%
df.drop(df.columns[[0,1,-1,-2,-3,-4,-5,-6,-9,-10,-11,12]],axis=1,inplace=True)

# %%
df=df.iloc[:-1-2-3-4-5]

# %%
df= df.fillna(str(0))

# %%
df
# Out:
#              Country,Other    TotalCase  NewCases TotalDeaths NewDeaths  \
# 0            North America  3,95,30,576     8,157    8,85,806       239
# 1                     Asia  4,97,38,601  2,48,218    6,56,920     4,378
# 2            South America  2,78,51,515     6,782    7,56,544        98
# 3                   Europe  4,62,83,283    38,828   10,63,480     1,374
# 4                   Africa    48,13,221     3,652    1,29,083        58
# ..                     ...          ...       ...         ...       ...
# 218           Vatican City           27         0           0         0
# 219  Saint Pierre Miquelon           25         0           0         0
# 220             Montserrat           20         0           1         0
# 221        Solomon Islands           20         0           0         0
# 222         Western Sahara           10         0           1         0
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# ...

# %%
import pandas as pd
for i in df.columns:
    df[i]=df[i].apply(lambda x:x.replace(',','').replace('+',''))

# %%
df.head()
# Out:
#    Country,Other TotalCase NewCases TotalDeaths NewDeaths TotalRecovered  \
# 0  North America  39530576     8157      885806       239       32231770
# 1           Asia  49738601   248218      656920      4378       45122397
# 2  South America  27851515     6782      756544        98       25123846
# 3         Europe  46283283    38828     1063480      1374       42930300
# 4         Africa   4813221     3652      129083        58        4340284
#
#   NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop Population  \
# 0         9782     6413000            14684                0          0
# 1       304122     3959284            31543                0          0
# 2         7577     1971125            29228                0          0
# 3        97628     2289503            17991                0          0
# 4         3534      343854             2764                0          0
#
#        Continent
# 0  North America
# 1           Asia
# 2  South America
# 3         Europe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     223 non-null    object
#  1   TotalCase         223 non-null    object
#  2   NewCases          223 non-null    object
#  3   TotalDeaths       223 non-null    object
#  4   NewDeaths         223 non-null    object
#  5   TotalRecovered    223 non-null    object
#  6   NewRecovered      223 non-null    object
#  7   ActiveCases       223 non-null    object
#  8   Serious,Critical  223 non-null    object
#  9   Tot Cases/1M pop  223 non-null    object
#  10  Population        223 non-null    object
#  11  Continent         223 non-null    object
# dtypes: object(12)
# memory usage: 21.0+ KB

# %%
df.columns=['CountryOther','TotalCase','NewCases','TotalDeaths','NewDeaths','TotalRecovered','NewRecovered','ActiveCases','SeriousCritical','TotCases1M pop','Population','Continent']

# %%
df["TotalCase"]=df['TotalCase'].astype(float)
df["NewCases"]=df['NewCases'].astype(float)
df["TotalDeaths"]=df['TotalDeaths'].astype(float)
df["NewDeaths"]=df['NewDeaths'].astype(float)
df["TotalRecovered"]=df['TotalRecovered'].astype(float)
df["NewRecovered"]=df['NewRecovered'].astype(float)
df["ActiveCases"]=df['ActiveCases'].astype(float)
df["NewRecovered"]=df['NewRecovered'].astype(float)
df["SeriousCritical"]=df["SeriousCritical"].astype(float)
df["TotCases1M pop"]=df["TotCases1M pop"].astype(float)
df["Population"]=df["Population"].astype(float)

# %%
df
# Out:
#               CountryOther   TotalCase  NewCases  TotalDeaths  NewDeaths  \
# 0            North America  39530576.0    8157.0     885806.0      239.0
# 1                     Asia  49738601.0  248218.0     656920.0     4378.0
# 2            South America  27851515.0    6782.0     756544.0       98.0
# 3                   Europe  46283283.0   38828.0    1063480.0     1374.0
# 4                   Africa   4813221.0    3652.0     129083.0       58.0
# ..                     ...         ...       ...          ...        ...
# 218           Vatican City        27.0       0.0          0.0        0.0
# 219  Saint Pierre Miquelon        25.0       0.0          0.0        0.0
# 220             Montserrat        20.0       0.0          1.0        0.0
# 221        Solomon Islands        20.0       0.0          0.0        0.0
# 222         Western Sahara        10.0       0.0          1.0        0.0
#
#      TotalRecovered  NewRecovered  ActiveCases  SeriousCritical  \
# ...

# %%
df.dtypes
# Out:
# CountryOther        object
# TotalCase          float64
# NewCases           float64
# TotalDeaths        float64
# NewDeaths          float64
# TotalRecovered     float64
# NewRecovered       float64
# ActiveCases        float64
# SeriousCritical    float64
# TotCases1M pop     float64
# Population         float64
# Continent           object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
sns.distplot(df.TotalCase,bins=12)
plt.show()
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.ActiveCases,bins=20)
plt.show()
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.NewCases)
plt.show()
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#joint plot 
sns.jointplot(x = df['TotalCase'], y = df['TotalDeaths'], kind = 'reg')

# %%
# pair plots 
sns.pairplot(df)

# %%
#countplot 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pandemic
pandemic.figure(figsize=(9,9))
sns.countplot(x='CountryOther',data=df, color="g")
# Out:
# <AxesSubplot:xlabel='CountryOther', ylabel='count'>

# %%
# swarmplots
import seaborn as sns
sns.swarmplot(y = df['TotalDeaths'], x = df['NewDeaths'])
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 97.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 87.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HOME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df.TotalRecovered)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(y=df.SeriousCritical)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.violinplot(x=df.TotalRecovered)
# Out:
# <AxesSubplot:xlabel='TotalRecovered'>

# %%
df['NewDeaths'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
df[0:30].plot.area(alpha=0.4,figsize=(12,3))
plt.legend(loc='center right',bbox_to_anchor=(1.0,0.5))
